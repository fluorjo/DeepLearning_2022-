# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# https://velog.io/@recoder/Colab%EA%B3%BC-Github-%EC%97%B0%EB%8F%99%ED%95%98%EA%B8%B0

# %%
#!git clone https://fluorjo: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@github.com/fluorjo/review_deeplearning_pytorch.git

# %%
#!git config --global user.email 'fluorjo@naver.com'
#!git config --global user.name 'fluorjo'

# %%
#cd /content/drive/MyDrive/code_colab

# %%
folder='/content/drive/MyDrive/code_colab/review_deeplearning_pytorch'

# %%
cd folder
# Out:
# /content/drive/MyDrive/code_colab/review_deeplearning_pytorch

# %%
commit_massage='2'

# %%
# !git add .
# !git commit -m commit_massage
# !git push
# Out:
# [master 99ef468] commit_massage
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite "\341\204\203\341\205\265\341\206\270\341\204\205\341\205\245\341\204\202\341\205\265\341\206\274-\341\204\221\341\205\241\341\204\213\341\205\265\341\204\220\341\205\251\341\204\216\341\205\265 \341\204\207\341\205\251\341\206\250\341\204\211\341\205\263\341\206\2701.ipynb" (90%)
# Counting objects: 3, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 1.21 KiB | 155.00 KiB/s, done.
# Total 3 (delta 1), reused 0 (delta 0)
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/fluorjo/review_deeplearning_pytorch.git
#    f19668d..99ef468  master -> master
