# %% [markdown]
# # 사전 훈련된 영어 Word2Vec
#
# - 구글에서 제공(300만 단어)
# - 다운로드 경로:"https://drive.google.com/u/0/uc?id=0B7XkCwpI5KDYNlNUTTlSS21pQmM&export=download&confirm=t"

# %%
# !wget -c "https://drive.google.com/u/0/uc?id=0B7XkCwpI5KDYNlNUTTlSS21pQmM&export=download&confirm=t"
# Out:
# --2022-05-27 06:25:56--  https://drive.google.com/u/0/uc?id=0B7XkCwpI5KDYNlNUTTlSS21pQmM&export=download&confirm=t
# Resolving drive.google.com (drive.google.com)... 172.253.115.100, 172.253.115.139, 172.253.115.102, ...
# Connecting to drive.google.com (drive.google.com)|172.253.115.100|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://drive.google.com/uc?id=0B7XkCwpI5KDYNlNUTTlSS21pQmM&export=download&confirm=t [following]
# --2022-05-27 06:25:56--  https://drive.google.com/uc?id=0B7XkCwpI5KDYNlNUTTlSS21pQmM&export=download&confirm=t
# Reusing existing connection to drive.google.com:443.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-0g-8s-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/92ga7hmlq7ief07nnn959suf7krbque5/1653632700000/06848720943842814915/*/0B7XkCwpI5KDYNlNUTTlSS21pQmM?e=download [following]
# ...

# %%
# Out:
# total 1608452
# drwxr-xr-x 1 root root       4096 May 17 13:39  sample_data
# -rw-r--r-- 1 root root 1647046227 May 27 06:26 'uc?id=0B7XkCwpI5KDYNlNUTTlSS21pQmM&export=download&confirm=t'

# %%
# !mv 'uc?id=0B7XkCwpI5KDYNlNUTTlSS21pQmM&export=download&confirm=t'
