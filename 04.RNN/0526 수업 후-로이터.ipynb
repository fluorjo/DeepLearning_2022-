# %% [markdown]
# 1.   로이터 뉴스-단어수, 최대 길이 변경해서 모델 돌려보기.
# 2.   로이터 뉴스-embedding vector의 갯수, LSTM unit 갯수 변경해서 돌려보기.

# %% [markdown]
# # 로이터 뉴스 분류하기 -LSTM

# %% [markdown]
# 데이터 탐색

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import reuters

# %%
(X_train, y_train),(X_test,y_test) = reuters.load_data()
len(X_train),len(X_test)
# Out:
# ...
# 2121728/2110848 [==============================] - 0s 0us/step
# (8982, 2246)

# %%
#카테고리 개수
max(y_train) + 1
# Out:
# 46

# %%
#첫번째 뉴스
print(X_train[0])
# Out:
# [1, 27595, 28842, 8, 43, 10, 447, 5, 25, 207, 270, 5, 3095, 111, 16, 369, 186, 90, 67, 7, 89, 5, 19, 102, 6, 19, 124, 15, 90, 67, 84, 22, 482, 26, 7, 48, 4, 49, 8, 864, 39, 209, 154, 6, 151, 6, 83, 11, 15, 22, 155, 11, 15, 7, 48, 9, 4579, 1005, 504, 6, 258, 6, 272, 11, 15, 22, 134, 44, 11, 15, 16, 8, 197, 1245, 90, 67, 52, 29, 209, 30, 32, 132, 6, 109, 15, 17, 12]

# %%
type(reuters.get_word_index())
# Out:
# ...
# 565248/550378 [==============================] - 0s 0us/step
# dict

# %%
reuters.get_word_index()['the']
#가장 빈도 높은 단어 = the
# Out:
# 1

# %%
index_word = {}
for key, value in reuters.get_word_index().items():
    index_word[value] = key
len(index_word)
# Out:
# 30979

# %%
#첫번째 기사 복원
' '.join(index_word[index] for index in X_train[0])
# Out:
# 'the wattie nondiscriminatory mln loss for plc said at only ended said commonwealth could 1 traders now april 0 a after said from 1985 and from foreign 000 april 0 prices its account year a but in this mln home an states earlier and rise and revs vs 000 its 16 vs 000 a but 3 psbr oils several and shareholders and dividend vs 000 its all 4 vs 000 1 mln agreed largely april 0 are 2 states will billion total and against 000 pct dlrs'

# %%
#뉴스 기사의 길이 - 최대, 평균
max(len(s) for s in X_train), sum(map(len,X_train)) / len(X_train)
# Out:
# (2376, 145.5398574927633)

# %%
# 뉴스 기사 단어 수의 분포
plt.hist([len(s) for s in X_train], bins=50)
plt.xlabel('length of samples')
plt.ylabel('number of samples')
plt.show()

# %%
#뉴스 그룹의 분포
plt.figure(figsize=(12,5))
sns.countplot(y_train);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# - 최대 길이는 2376이지만 단어 수 분포 보면 500개 아래에 모여있다. 이대로라면 1800개의 패딩을 겁나 넣어야 한다. 또 사실 중요한 말은 다 앞에 있다.
# 그래서 일정 단어 수 이하로 자르는 게 나을 수 있다.
#
# - 단어 수는 30979개지만 이걸 다 쓰진 않을 것. 잘 쓰지 않는 단어까지 포함하는 것도 별로다.

# %% [markdown]
# # LSTM으로 로이터 뉴스 분류
# - 문장 길이:100단어까지(최대-2376)
# - 단어:빈도 수 기준 1000개 까지만.

# %%
max_words=1000
max_len=100

# %%
(X_train, y_train),(X_test,y_test) = reuters.load_data(
    num_words=max_words,
    test_split=0.2
)
len(X_train),len(X_test)
# Out:
# (8982, 2246)

# %%
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Embedding, LSTM, Dense
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical

# %%
X_train=pad_sequences(X_train,maxlen=max_len)
X_test=pad_sequences(X_test,maxlen=max_len)
Y_train=to_categorical(y_train)
Y_test=to_categorical(y_test)
X_train.shape,X_test.shape,Y_train.shape,Y_test.shape
# Out:
# ((8982, 100), (2246, 100), (8982, 46), (2246, 46))

# %% [markdown]
# - 모델 정의/실행/학습

# %%
model=Sequential([
                  Embedding(max_words,64,input_length=max_len),
                  LSTM(100),
                  Dense(46,activation='softmax')
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  embedding (Embedding)       (None, 100, 64)           64000
#
#  lstm (LSTM)                 (None, 100)               66000
#
#  dense (Dense)               (None, 46)                4646
#
# ...
# Total params: 134,646
# Trainable params: 134,646
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile('adam','categorical_crossentropy',['accuracy'])

# %%
model_path='best-reuters-lstm.h5'
mc=ModelCheckpoint(model_path,verbose=1,save_best_only=True)
es=EarlyStopping(patience=10)

# %%
hist=model.fit(
    X_train,Y_train,validation_split=0.2,
    epochs=100,batch_size=128,callbacks=[mc,es]
)
# Out:
# Epoch 1/100
# 53/57 [==========================>...] - ETA: 0s - loss: 2.7630 - accuracy: 0.3485
# Epoch 1: val_loss improved from inf to 2.41013, saving model to best-reuters-lstm.h5
# 57/57 [==============================] - 8s 22ms/step - loss: 2.7472 - accuracy: 0.3466 - val_loss: 2.4101 - val_accuracy: 0.3450
# Epoch 2/100
# 57/57 [==============================] - ETA: 0s - loss: 2.3962 - accuracy: 0.3552
# Epoch 2: val_loss improved from 2.41013 to 2.22823, saving model to best-reuters-lstm.h5
# 57/57 [==============================] - 1s 12ms/step - loss: 2.3962 - accuracy: 0.3552 - val_loss: 2.2282 - val_accuracy: 0.4814
# Epoch 3/100
# 53/57 [==========================>...] - ETA: 0s - loss: 2.0961 - accuracy: 0.4814
# Epoch 3: val_loss improved from 2.22823 to 2.02604, saving model to best-reuters-lstm.h5
# 57/57 [==============================] - 1s 12ms/step - loss: 2.0858 - accuracy: 0.4846 - val_loss: 2.0260 - val_accuracy: 0.4947
# Epoch 4/100
# ...

# %%
best_model=load_model(model_path)
best_model.evaluate(X_test,Y_test)
# Out:
# 71/71 [==============================] - 1s 5ms/step - loss: 1.3264 - accuracy: 0.6937
# [1.326447606086731, 0.6936776638031006]

# %% [markdown]
# 학습과정 시각화

# %%
y_acc=hist.history['accuracy']
y_loss=hist.history['loss']
xs=np.arange(1,len(y_acc)+1)
import matplotlib.pyplot as plt
plt.figure(figsize=(12,8))
plt.plot(xs,y_acc,label='accuracy')
plt.plot(xs,y_loss,label='loss')
plt.legend(),plt.grid()
plt.ylim(0,1.2),plt.xlabel('Epoch')
plt.show()

# %% [markdown]
# # 수치 바꿔가며 모델 돌려보기
# 단어수, 최대 길이,embedding vector의 갯수, LSTM unit 갯수

# %%
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Embedding, LSTM, Dense
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical

def model_on(max_words,max_len,num_vector,num_unit):
    (X_train, y_train),(X_test,y_test) = reuters.load_data(num_words=max_words,test_split=0.2)
    X_train=pad_sequences(X_train,maxlen=max_len)
    X_test=pad_sequences(X_test,maxlen=max_len)
    Y_train=to_categorical(y_train)
    Y_test=to_categorical(y_test)

    model=Sequential([Embedding(max_words,num_vector,input_length=max_len),LSTM(num_unit),Dense(46,activation='softmax')])

    model.compile('adam','categorical_crossentropy',['accuracy'])

    model_path='best-reuters-lstm.h5'
    mc=ModelCheckpoint(model_path,verbose=1,save_best_only=True)
    es=EarlyStopping(patience=10)
    hist=model.fit(X_train,Y_train,validation_split=0.2,epochs=100,batch_size=128,callbacks=[mc,es])

    best_model=load_model(model_path)
    return best_model.evaluate(X_test,Y_test)

# %%
model_on(1000,200,64,100)
#[1.2070716619491577, 0.7168298959732056]

# %%
model_on(1000,300,64,100)
#[1.1390318870544434, 0.7373107671737671]

# %%
model_on(2000,300,128,200)
#[1.3525351285934448, 0.6803205609321594]

# %%
model_on(1500,400,64,150)
#[1.551456332206726, 0.6139804124832153]

# %%
model_on(1000,400,128,100)
#[1.1721478700637817, 0.7266250848770142]

# %% [markdown]
# 학습과정 시각화

# %%
y_acc=hist.history['accuracy']
y_loss=hist.history['loss']
xs=np.arange(1,len(y_acc)+1)
import matplotlib.pyplot as plt
plt.figure(figsize=(12,8))
plt.plot(xs,y_acc,label='accuracy')
plt.plot(xs,y_loss,label='loss')
plt.legend(),plt.grid()
plt.ylim(0,1.2),plt.xlabel('Epoch')
plt.show()
