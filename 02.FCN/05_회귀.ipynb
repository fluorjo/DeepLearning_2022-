# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
seed=2022
np.random.seed(seed)
tf.random.set_seed(seed)

# %%
from sklearn.datasets import fetch_california_housing
house = fetch_california_housing()

# %%
df=pd.DataFrame(house.data,columns=house.feature_names)
df['target']=house.target
df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  target
# 0    -122.23   4.526
# 1    -122.22   3.585
# 2    -122.24   3.521
# 3    -122.25   3.413
# 4    -122.25   3.422

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(
    house.data, house.target, test_size=0.1, random_state=seed
)

X_train.shape, X_test.shape, Y_train.shape, Y_test.shape
# Out:
# ((18576, 8), (2064, 8), (18576,), (2064,))

# %% [markdown]
# - 회귀모델 정의/설정/학습/평가

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
pred=model.predic(X_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-8cb7f7d316a0> in <module>()
# ----> 1 pred=model.predic(X_test)
#
# NameError: name 'model' is not defined

# %%
pred=model.predic(X_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-8cb7f7d316a0> in <module>()
# ----> 1 pred=model.predic(X_test)
#
# NameError: name 'model' is not defined

# %%
pft=pd.DataFrame({'y_test':y_test,'pred':pred.flatten()})
dft
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-f1a79e355959> in <module>()
# ----> 1 pft=pd.DataFrame({'y_test':y_test,'pred':pred.flatten()})
#       2 dft
#
# NameError: name 'y_test' is not defined
